# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import datasets

# %%
DATA_URL = "http://lib.stat.cmu.edu/datasets/boston"
raw_df = pd.read_csv(DATA_URL, sep="\s+", skiprows=22, header=None)
data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
target = raw_df.values[1::2, 2]

# %%
X_boston = pd.DataFrame(data)
y_boston = pd.DataFrame(target)
df_boston = pd.concat([X_boston, y_boston], axis=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 2
#       1 X_boston = pd.DataFrame(data)
# ----> 2 y_boston = pd.DataFrane(target)
#
# AttributeError: module 'pandas' has no attribute 'DataFrane'
